# %% [markdown]
# <a href="https://colab.research.google.com/github/Zuhair0000/FYP-Research/blob/main/Research_Dataset_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# List all files in the Colab working directory
print(os.listdir("/content"))
# Out:
# ['.config', 'Dataset A', 'Dataset B', '.ipynb_checkpoints', 'ML_DL_Comparison.csv', 'sample_data']

# %%
import glob
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import joblib
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
all_files = glob.glob("/content/Dataset A/*.xlsx")
print("All Excel files:", all_files)

# Separate solar and wind
solar_files = [f for f in all_files if "光伏" in f]
wind_files  = [f for f in all_files if "风力" in f]

print("Solar files:", solar_files)
print("Wind files:", wind_files)
# Out:
# All Excel files: ['/content/Dataset A/风力冬季发电.xlsx', '/content/Dataset A/光伏秋季发电.xlsx', '/content/Dataset A/风力夏季发电.xlsx', '/content/Dataset A/风力秋季发电.xlsx', '/content/Dataset A/光伏冬季发电.xlsx', '/content/Dataset A/光伏春季发电.xlsx', '/content/Dataset A/光伏夏季发电.xlsx', '/content/Dataset A/风力春季发电.xlsx']
# Solar files: ['/content/Dataset A/光伏秋季发电.xlsx', '/content/Dataset A/光伏冬季发电.xlsx', '/content/Dataset A/光伏春季发电.xlsx', '/content/Dataset A/光伏夏季发电.xlsx']
# Wind files: ['/content/Dataset A/风力冬季发电.xlsx', '/content/Dataset A/风力夏季发电.xlsx', '/content/Dataset A/风力秋季发电.xlsx', '/content/Dataset A/风力春季发电.xlsx']

# %%
# Load solar
solar_dfs = [pd.read_excel(f) for f in solar_files]
solar_data = pd.concat(solar_dfs, ignore_index=True)

# Load wind
wind_dfs = [pd.read_excel(f) for f in wind_files]
wind_data = pd.concat(wind_dfs, ignore_index=True)

print("Solar shape:", solar_data.shape)
print("Wind shape:", wind_data.shape)
# Out:
# Solar shape: (8753, 7)
# Wind shape: (8752, 5)

# %%
print("Solar columns:", solar_data.columns)
print(solar_data.head())

print("\nWind columns:", wind_data.columns)
print(wind_data.head())

print("\nMissing values in Solar:\n", solar_data.isnull().sum())
print("\nMissing values in Wind:\n", wind_data.isnull().sum())
# Out:
# Solar columns: Index(['年份', '时间', '温度', '湿度', '地面辐射强度', '大气上层辐射强度', '光伏发电'], dtype='object')
#                    年份  时间      温度     湿度  地面辐射强度  大气上层辐射强度  光伏发电
# 0 2019-09-01 00:00:00   1  11.281  0.009   0.000     0.000   0.0
# 1 2019-09-01 01:00:00   2  10.447  0.009   0.000     0.000   0.0
# 2 2019-09-01 02:00:00   3   9.970  0.009   0.000     0.000   0.0
# 3 2019-09-01 03:00:00   4   9.942  0.009   0.000     0.000   0.0
# 4 2019-09-01 04:00:00   5   9.962  0.009   2.222     7.152   0.0
#
# Wind columns: Index(['年份', '时间', '空气密度', '风速', '发电功率'], dtype='object')
#                    年份  时间   空气密度     风速      发电功率
# 0 2019-12-01 00:00:00   1  1.318  8.285  2578.960
# 1 2019-12-01 01:00:00   2  1.314  7.990  2379.431
# 2 2019-12-01 02:00:00   3  1.309  7.685  2162.803
# 3 2019-12-01 03:00:00   4  1.304  7.547  2068.773
# 4 2019-12-01 04:00:00   5  1.302  7.058  1740.835
#
# Missing values in Solar:
#  年份          0
# 时间          0
# 温度          0
# 湿度          0
# 地面辐射强度      0
# 大气上层辐射强度    0
# 光伏发电        0
# dtype: int64
#
# Missing values in Wind:
#  年份      0
# 时间      0
# 空气密度    0
# 风速      0
# 发电功率    0
# dtype: int64

# %%
# --- Solar ---
solar_data = solar_data.rename(columns={
    "年份": "DateTime",
    "时间": "Index",
    "温度": "Temperature",
    "湿度": "Humidity",
    "地面辐射强度": "Ground_Irradiance",
    "大气上层辐射强度": "Atmospheric_Irradiance",
    "光伏发电": "Solar_Power"
})

# --- Wind ---
wind_data = wind_data.rename(columns={
    "年份": "DateTime",
    "时间": "Index",
    "空气密度": "Air_Density",
    "风速": "Wind_Speed",
    "发电功率": "Wind_Power"
})

# %%
solar_data["DateTime"] = pd.to_datetime(solar_data["DateTime"])
wind_data["DateTime"]  = pd.to_datetime(wind_data["DateTime"])

# Sort by datetime
solar_data = solar_data.sort_values("DateTime")
wind_data  = wind_data.sort_values("DateTime")
solar_data
# Out:
#                 DateTime  Index  Temperature  Humidity  Ground_Irradiance  \
# 2928 2019-01-01 08:00:00    745      -19.889     0.001             82.680
# 2929 2019-01-01 09:00:00    746      -19.004     0.001            149.553
# 2930 2019-01-01 10:00:00    747      -17.971     0.001            193.625
# 2931 2019-01-01 11:00:00    748      -17.281     0.001            203.808
# 2932 2019-01-01 12:00:00    749      -16.738     0.001            185.193
# ...                  ...    ...          ...       ...                ...
# 2923 2019-12-31 19:00:00    740      -23.621     0.000              0.000
# 2924 2019-12-31 20:00:00    741      -23.980     0.000              0.000
# 2925 2019-12-31 21:00:00    742      -24.826     0.000              0.000
# 2926 2019-12-31 22:00:00    743      -26.172     0.000              0.000
# 2927 2019-12-31 23:00:00    744      -26.994     0.000              0.000
#
#       Atmospheric_Irradiance  Solar_Power
# 2928                 209.252      257.690
# 2929                 345.604      530.391
# 2930                 430.654      871.016
# 2931                 458.550     1087.304
# 2932                 427.391     1010.161
# ...                      ...          ...
# 2923                   0.000        0.000
# 2924                   0.000        0.000
# 2925                   0.000        0.000
# 2926                   0.000        0.000
# 2927                   0.000        0.000
#
# [8753 rows x 7 columns]

# %%
solar_data = solar_data.drop(columns=["Index"])
wind_data  = wind_data.drop(columns=["Index"])

# %%
print("Solar date range:", solar_data["DateTime"].min(), "→", solar_data["DateTime"].max())
print("Wind date range:", wind_data["DateTime"].min(), "→", wind_data["DateTime"].max())

print("\nSolar frequency check:")
print(solar_data["DateTime"].diff().value_counts().head())

print("\nWind frequency check:")
print(wind_data["DateTime"].diff().value_counts().head())
# Out:
# Solar date range: 2019-01-01 08:00:00 → 2019-12-31 23:00:00
# Wind date range: 2019-01-01 08:00:00 → 2019-12-31 23:00:00
#
# Solar frequency check:
# DateTime
# 0 days 01:00:00    8751
# 0 days 00:00:00       1
# Name: count, dtype: int64
#
# Wind frequency check:
# DateTime
# 0 days 01:00:00    8751
# Name: count, dtype: int64

# %%
# Resample Solar
solar_data = solar_data.set_index("DateTime").resample("h").mean().interpolate()

# Resample Wind
wind_data = wind_data.set_index("DateTime").resample("h").mean().interpolate()

# Reset index back
solar_data = solar_data.reset_index()
wind_data  = wind_data.reset_index()

# %%
merged_data = pd.merge_asof(
    solar_data.sort_values("DateTime"),
    wind_data.sort_values("DateTime"),
    on="DateTime",
    direction="nearest"  # matches closest timestamp
)
merged_data
# Out:
#                 DateTime  Temperature  Humidity  Ground_Irradiance  \
# 0    2019-01-01 08:00:00      -19.889     0.001             82.680
# 1    2019-01-01 09:00:00      -19.004     0.001            149.553
# 2    2019-01-01 10:00:00      -17.971     0.001            193.625
# 3    2019-01-01 11:00:00      -17.281     0.001            203.808
# 4    2019-01-01 12:00:00      -16.738     0.001            185.193
# ...                  ...          ...       ...                ...
# 8747 2019-12-31 19:00:00      -23.621     0.000              0.000
# 8748 2019-12-31 20:00:00      -23.980     0.000              0.000
# 8749 2019-12-31 21:00:00      -24.826     0.000              0.000
# 8750 2019-12-31 22:00:00      -26.172     0.000              0.000
# 8751 2019-12-31 23:00:00      -26.994     0.000              0.000
#
#       Atmospheric_Irradiance  Solar_Power  Air_Density  Wind_Speed  Wind_Power
# 0                    209.252      257.690        1.335       6.178    1203.800
# 1                    345.604      530.391        1.337       6.534    1410.415
# 2                    430.654      871.016        1.339       6.747    1547.633
# 3                    458.550     1087.304        1.340       6.765    1556.072
# 4                    427.391     1010.161        1.342       6.606    1456.741
# ...                      ...          ...          ...         ...         ...
# 8747                   0.000        0.000        1.385       6.260    1254.654
# 8748                   0.000        0.000        1.387       5.784     995.959
# 8749                   0.000        0.000        1.388       4.955     614.468
# 8750                   0.000        0.000        1.388       4.525     457.358
# 8751                   0.000        0.000        1.389       4.402     417.579
#
# [8752 rows x 9 columns]

# %%
for lag in [1, 3, 6, 24]:  # 1h, 3h, 6h, 24h lags
    merged_data[f"Solar_Power_lag{lag}"] = merged_data["Solar_Power"].shift(lag)
    merged_data[f"Wind_Power_lag{lag}"] = merged_data["Wind_Power"].shift(lag)

# %%
merged_data["Solar_Power_roll6h"] = merged_data["Solar_Power"].rolling(window=6).mean()
merged_data["Wind_Power_roll6h"] = merged_data["Wind_Power"].rolling(window=6).mean()

# %%
merged_data["hour"] = merged_data["DateTime"].dt.hour
merged_data["dayofweek"] = merged_data["DateTime"].dt.dayofweek
merged_data["month"] = merged_data["DateTime"].dt.month

# %%
merged_data = merged_data.dropna().reset_index(drop=True)

# %% [markdown]
# ### ***ML Dataset A***

# %%
# ========== Metrics Function ==========
def get_metrics(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae  = mean_absolute_error(y_true, y_pred)
    r2   = r2_score(y_true, y_pred)
    return rmse, mae, r2

# %%
# ========== Evaluation Function ==========
def evaluate_model(model, X_train, y_train, X_test, y_test, name="Model", target="Solar"):
    preds_train = model.predict(X_train)
    preds_test  = model.predict(X_test)

    rmse, mae, r2 = get_metrics(y_test, preds_test)

    print(f"\n{name} Performance on {target}:")
    print(f"RMSE: {rmse:.2f}, MAE: {mae:.2f}, R²: {r2:.3f}")

    # Plot Actual vs Predicted (sample of 200 hours)
    plt.figure(figsize=(10,5))
    plt.plot(y_test.values[:200], label="Actual")
    plt.plot(preds_test[:200], label="Predicted")
    plt.title(f"{name} - {target} Power Prediction (Sample of 200 hours)")
    plt.legend()
    plt.show()

    return {"Target": target, "Model": name, "RMSE": rmse, "MAE": mae, "R2": r2}

# %%
# --- Features & Targets ---
solar_features = ["Temperature", "Humidity", "Ground_Irradiance", "Atmospheric_Irradiance"]
wind_features  = ["Air_Density", "Wind_Speed"]

X_solar = merged_data[solar_features]
y_solar = merged_data["Solar_Power"]

X_wind  = merged_data[wind_features]
y_wind  = merged_data["Wind_Power"]

# %%
# --- Train-Test Split ---
X_train_solar_ml, X_test_solar_ml, y_train_solar_ml, y_test_solar_ml = train_test_split(X_solar, y_solar, test_size=0.2, shuffle=False)
X_train_wind_ml,  X_test_wind_ml,  y_train_wind_ml,  y_test_wind_ml  = train_test_split(X_wind,  y_wind,  test_size=0.2, shuffle=False)

# %%
# --- Scaling ---
scaler_solar = StandardScaler()
X_train_solar_ml = scaler_solar.fit_transform(X_train_solar_ml)
X_test_solar_ml  = scaler_solar.transform(X_test_solar_ml)

scaler_wind = StandardScaler()
X_train_wind_ml = scaler_wind.fit_transform(X_train_wind_ml)
X_test_wind_ml  = scaler_wind.transform(X_test_wind_ml)

# %% [markdown]
# # Training For Solar

# %%
rf_solar = RandomForestRegressor(n_estimators=200, random_state=42)
rf_solar.fit(X_train_solar_ml, y_train_solar_ml)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=42)

# %%
xgb_solar = XGBRegressor(n_estimators=200, learning_rate=0.1, max_depth=6, random_state=42)
xgb_solar.fit(X_train_solar_ml, y_train_solar_ml)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=200,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# ### Training for Wind

# %%
rf_wind = RandomForestRegressor(n_estimators=200, random_state=42)
rf_wind.fit(X_train_wind_ml, y_train_wind_ml)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=42)

# %%
xgb_wind = XGBRegressor(n_estimators=200, learning_rate=0.1, max_depth=6, random_state=42)
xgb_wind.fit(X_train_wind_ml, y_train_wind_ml)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=200,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# ## **Evaluation**

# %%
results_ml = []

# %%
# Solar
results_ml.append(evaluate_model(rf_solar,  X_train_solar_ml, y_train_solar_ml, X_test_solar_ml, y_test_solar_ml, "Random Forest", "Solar"))
results_ml.append(evaluate_model(xgb_solar, X_train_solar_ml, y_train_solar_ml, X_test_solar_ml, y_test_solar_ml, "XGBoost", "Solar"))
# Out:
# Random Forest Performance on Solar:
# RMSE: 390.48, MAE: 171.89, R²: 0.865
# XGBoost Performance on Solar:
# RMSE: 394.17, MAE: 178.85, R²: 0.862

# %%
# Wind
results_ml.append(evaluate_model(rf_wind,  X_train_wind_ml, y_train_wind_ml, X_test_wind_ml, y_test_wind_ml, "Random Forest", "Wind"))
results_ml.append(evaluate_model(xgb_wind, X_train_wind_ml, y_train_wind_ml, X_test_wind_ml, y_test_wind_ml, "XGBoost", "Wind"))
# Out:
# Random Forest Performance on Wind:
# RMSE: 0.66, MAE: 0.36, R²: 1.000
# XGBoost Performance on Wind:
# RMSE: 8.62, MAE: 5.01, R²: 1.000

# %%
# Convert to DataFrame
results_df = pd.DataFrame(results_ml)
print("\nFinal Results:\n", results_df)
# Out:
# Final Results:
#    Target          Model        RMSE         MAE        R2
# 0  Solar  Random Forest  390.483799  171.886996  0.864690
# 1  Solar        XGBoost  394.166178  178.854385  0.862126
# 2   Wind  Random Forest    0.662368    0.364053  1.000000
# 3   Wind        XGBoost    8.615146    5.012414  0.999940

# %% [markdown]
# ### **DL for Dataset A**

# %%
# ========== Sequence Builder ==========
def create_sequences(X, y, window_size=24):
    Xs, ys = [], []
    for i in range(len(X) - window_size):
        Xs.append(X[i:i+window_size])
        ys.append(y[i+window_size])
    return np.array(Xs), np.array(ys)

# %%
# --- Solar ---
solar_features = ["Temperature", "Humidity", "Ground_Irradiance", "Atmospheric_Irradiance"]
X_solar = merged_data[solar_features].values
y_solar = merged_data["Solar_Power"].values

# %%
# --- Wind ---
wind_features = ["Air_Density", "Wind_Speed"]
X_wind = merged_data[wind_features].values
y_wind = merged_data["Wind_Power"].values

# %%
# --- Scaling ---
scaler_solar = MinMaxScaler()
X_solar_scaled = scaler_solar.fit_transform(X_solar)

scaler_wind = MinMaxScaler()
X_wind_scaled = scaler_wind.fit_transform(X_wind)

y_solar_scaled = MinMaxScaler().fit_transform(y_solar.reshape(-1,1)).flatten()
y_wind_scaled  = MinMaxScaler().fit_transform(y_wind.reshape(-1,1)).flatten()

# %%
# --- Create Sequences ---
window = 24  # 24-hour lookback
X_solar_seq, y_solar_seq = create_sequences(X_solar_scaled, y_solar_scaled, window)
X_wind_seq,  y_wind_seq  = create_sequences(X_wind_scaled,  y_wind_scaled,  window)

# %%
print("Solar Seq Shape:", X_solar_seq.shape)
print("Wind Seq Shape:", X_wind_seq.shape)
# Out:
# Solar Seq Shape: (8704, 24, 4)
# Wind Seq Shape: (8704, 24, 2)

# %%
# --- Train/Val/Test Split ---
def split_data(X, y, train_size=0.7, val_size=0.15):
    n = len(X)
    train_end = int(train_size * n)
    val_end   = int((train_size+val_size) * n)
    return X[:train_end], y[:train_end], X[train_end:val_end], y[train_end:val_end], X[val_end:], y[val_end:]

X_train_solar_dl, y_train_solar_dl, X_val_solar_dl, y_val_solar_dl, X_test_solar_dl, y_test_solar_dl = split_data(X_solar_seq, y_solar_seq)
X_train_wind_dl,  y_train_wind_dl,  X_val_wind_dl,  y_val_wind_dl,  X_test_wind_dl,  y_test_wind_dl  = split_data(X_wind_seq, y_wind_seq)

# %%
# ========== Model Builders ==========

def build_lstm(input_shape):
    model = Sequential([
        LSTM(64, return_sequences=True, input_shape=input_shape),
        Dropout(0.2),
        LSTM(32),
        Dense(1)
    ])
    model.compile(optimizer="adam", loss="mse")
    return model

def build_gru(input_shape):
    model = Sequential([
        GRU(64, return_sequences=True, input_shape=input_shape),
        Dropout(0.2),
        GRU(32),
        Dense(1)
    ])
    model.compile(optimizer="adam", loss="mse")
    return model

# %% [markdown]
# ## **Training for Solar**

# %%
early_stop = EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)

# %%
# --- Solar LSTM ---
lstm_solar = build_lstm((X_train_solar_dl.shape[1], X_train_solar_dl.shape[2]))
history_lstm_solar = lstm_solar.fit(
    X_train_solar_dl, y_train_solar_dl,
    validation_data=(X_val_solar_dl, y_val_solar_dl),
    epochs=50, batch_size=32,
    callbacks=[early_stop], verbose=1
)
print("LSTM for Solar: ", lstm_solar)
# Out:
# Epoch 1/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - loss: 0.0606 - val_loss: 0.0367
# Epoch 2/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 12s 63ms/step - loss: 0.0264 - val_loss: 0.0305
# Epoch 3/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - loss: 0.0211 - val_loss: 0.0208
# Epoch 4/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 0.0181 - val_loss: 0.0198
# Epoch 5/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 19s 58ms/step - loss: 0.0158 - val_loss: 0.0208
# Epoch 6/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 0.0153 - val_loss: 0.0199
# Epoch 7/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 33ms/step - loss: 0.0145 - val_loss: 0.0156
# Epoch 8/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 0.0133 - val_loss: 0.0166
# Epoch 9/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 60ms/step - loss: 0.0132 - val_loss: 0.0154
# Epoch 10/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 12s 62ms/step - loss: 0.0122 - val_loss: 0.0159
# Epoch 11/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - loss: 0.0130 - val_loss: 0.0113
# Epoch 12/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 0.0125 - val_loss: 0.0165
# Epoch 13/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0120 - val_loss: 0.0122
# Epoch 14/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - loss: 0.0117 - val_loss: 0.0138
# Epoch 15/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.0128 - val_loss: 0.0127
# Epoch 16/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 0.0115 - val_loss: 0.0130
# Epoch 17/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - loss: 0.0109 - val_loss: 0.0122
# Epoch 18/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0109 - val_loss: 0.0136
# Epoch 19/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0106 - val_loss: 0.0133
# Epoch 20/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - loss: 0.0106 - val_loss: 0.0205
# Epoch 21/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - loss: 0.0107 - val_loss: 0.0118
# LSTM for Solar:  <Sequential name=sequential_16, built=True>

# %%
# --- Solar GRU ---
gru_solar = build_gru((X_train_solar_dl.shape[1], X_train_solar_dl.shape[2]))
history_gru_solar = gru_solar.fit(
    X_train_solar_dl, y_train_solar_dl,
    validation_data=(X_val_solar_dl, y_val_solar_dl),
    epochs=50, batch_size=32,
    callbacks=[early_stop], verbose=1
)
# Out:
# Epoch 1/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - loss: 0.0462 - val_loss: 0.0245
# Epoch 2/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - loss: 0.0218 - val_loss: 0.0180
# Epoch 3/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.0169 - val_loss: 0.0155
# Epoch 4/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0144 - val_loss: 0.0145
# Epoch 5/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.0149 - val_loss: 0.0137
# Epoch 6/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - loss: 0.0127 - val_loss: 0.0132
# Epoch 7/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - loss: 0.0121 - val_loss: 0.0124
# Epoch 8/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0132 - val_loss: 0.0142
# Epoch 9/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - loss: 0.0125 - val_loss: 0.0144
# Epoch 10/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0119 - val_loss: 0.0121
# Epoch 11/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - loss: 0.0113 - val_loss: 0.0112
# Epoch 12/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 0.0113 - val_loss: 0.0143
# Epoch 13/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - loss: 0.0113 - val_loss: 0.0115
# Epoch 14/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - loss: 0.0112 - val_loss: 0.0142
# Epoch 15/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - loss: 0.0112 - val_loss: 0.0129
# Epoch 16/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 39ms/step - loss: 0.0110 - val_loss: 0.0121
# Epoch 17/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.0115 - val_loss: 0.0121
# Epoch 18/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 38ms/step - loss: 0.0106 - val_loss: 0.0111
# Epoch 19/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - loss: 0.0113 - val_loss: 0.0151
# Epoch 20/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - loss: 0.0111 - val_loss: 0.0117
# Epoch 21/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - loss: 0.0107 - val_loss: 0.0126
# Epoch 22/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0100 - val_loss: 0.0119
# Epoch 23/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - loss: 0.0103 - val_loss: 0.0107
# Epoch 24/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0099 - val_loss: 0.0109
# Epoch 25/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.0097 - val_loss: 0.0117
# Epoch 26/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 27/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.0101 - val_loss: 0.0135
# Epoch 28/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 0.0096 - val_loss: 0.0119
# Epoch 29/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - loss: 0.0100 - val_loss: 0.0094
# Epoch 30/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 0.0099 - val_loss: 0.0122
# Epoch 31/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.0092 - val_loss: 0.0119
# Epoch 32/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0103 - val_loss: 0.0128
# Epoch 33/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 0.0095 - val_loss: 0.0089
# Epoch 34/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - loss: 0.0102 - val_loss: 0.0113
# Epoch 35/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.0093 - val_loss: 0.0103
# Epoch 36/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - loss: 0.0090 - val_loss: 0.0123
# Epoch 37/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.0095 - val_loss: 0.0091
# Epoch 38/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 0.0098 - val_loss: 0.0083
# Epoch 39/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - loss: 0.0097 - val_loss: 0.0122
# Epoch 40/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0091 - val_loss: 0.0096
# Epoch 41/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.0084 - val_loss: 0.0114
# Epoch 42/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - loss: 0.0086 - val_loss: 0.0096
# Epoch 43/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0090 - val_loss: 0.0079
# Epoch 44/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - loss: 0.0083 - val_loss: 0.0087
# Epoch 45/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 0.0088 - val_loss: 0.0082
# Epoch 46/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - loss: 0.0090 - val_loss: 0.0078
# Epoch 47/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 38ms/step - loss: 0.0086 - val_loss: 0.0087
# Epoch 48/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0082 - val_loss: 0.0085
# Epoch 49/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 0.0081 - val_loss: 0.0107
# Epoch 50/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.0083 - val_loss: 0.0087

# %% [markdown]
# ## **Training for Wind**

# %%
# --- Wind LSTM ---
lstm_wind = build_lstm((X_train_wind_dl.shape[1], X_train_wind_dl.shape[2]))
history_lstm_wind = lstm_wind.fit(
    X_train_wind_dl, y_train_wind_dl,
    validation_data=(X_val_wind_dl, y_val_wind_dl),
    epochs=50, batch_size=32,
    callbacks=[early_stop], verbose=1
)
# Out:
# Epoch 1/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - loss: 0.0448 - val_loss: 0.0234
# Epoch 2/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 0.0185 - val_loss: 0.0132
# Epoch 3/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 0.0117 - val_loss: 0.0093
# Epoch 4/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0091 - val_loss: 0.0069
# Epoch 5/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - loss: 0.0069 - val_loss: 0.0065
# Epoch 6/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 0.0062 - val_loss: 0.0050
# Epoch 7/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 0.0051 - val_loss: 0.0048
# Epoch 8/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 9/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 0.0044 - val_loss: 0.0040
# Epoch 10/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.0045 - val_loss: 0.0038
# Epoch 11/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - loss: 0.0039 - val_loss: 0.0038
# Epoch 12/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 13/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 14/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 0.0034 - val_loss: 0.0054
# Epoch 15/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0038 - val_loss: 0.0035
# Epoch 16/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - loss: 0.0034 - val_loss: 0.0037
# Epoch 17/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 18/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 0.0032 - val_loss: 0.0034
# Epoch 19/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 20/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0032 - val_loss: 0.0037
# Epoch 21/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 22/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0032 - val_loss: 0.0034
# Epoch 23/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 24/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 25/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 0.0029 - val_loss: 0.0037
# Epoch 26/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 27/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 28/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 29/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 30/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 31/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 32/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 33/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 34/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0028 - val_loss: 0.0034
# Epoch 35/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 36/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 37/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0027 - val_loss: 0.0035
# Epoch 38/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 39/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 40/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - loss: 0.0026 - val_loss: 0.0031
# Epoch 41/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 42/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 43/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 44/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 45/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0026 - val_loss: 0.0034
# Epoch 46/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - loss: 0.0026 - val_loss: 0.0032
# Epoch 47/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 48/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - loss: 0.0026 - val_loss: 0.0032
# Epoch 49/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0027 - val_loss: 0.0032
# Epoch 50/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.0026 - val_loss: 0.0031

# %%
# --- Wind GRU ---
gru_wind = build_gru((X_train_wind_dl.shape[1], X_train_wind_dl.shape[2]))
history_gru_wind = gru_wind.fit(
    X_train_wind_dl, y_train_wind_dl,
    validation_data=(X_val_wind_dl, y_val_wind_dl),
    epochs=50, batch_size=32,
    callbacks=[early_stop], verbose=1
)
# Out:
# Epoch 1/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - loss: 0.0467 - val_loss: 0.0131
# Epoch 2/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - loss: 0.0114 - val_loss: 0.0100
# Epoch 3/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.0080 - val_loss: 0.0066
# Epoch 4/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - loss: 0.0070 - val_loss: 0.0058
# Epoch 5/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 6/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0057 - val_loss: 0.0047
# Epoch 7/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.0050 - val_loss: 0.0046
# Epoch 8/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.0045 - val_loss: 0.0053
# Epoch 9/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 10/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.0040 - val_loss: 0.0043
# Epoch 11/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 12/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 33ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 13/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - loss: 0.0035 - val_loss: 0.0036
# Epoch 14/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0032 - val_loss: 0.0037
# Epoch 15/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.0031 - val_loss: 0.0036
# Epoch 16/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 17/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - loss: 0.0032 - val_loss: 0.0039
# Epoch 18/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - loss: 0.0030 - val_loss: 0.0036
# Epoch 19/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 20/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 21/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0030 - val_loss: 0.0036
# Epoch 22/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - loss: 0.0030 - val_loss: 0.0041
# Epoch 23/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 24/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 25/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - loss: 0.0028 - val_loss: 0.0036
# Epoch 26/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 27/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 39ms/step - loss: 0.0029 - val_loss: 0.0035
# Epoch 28/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 29/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 30/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 31/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 32/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 0.0027 - val_loss: 0.0032
# Epoch 33/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 34/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - loss: 0.0028 - val_loss: 0.0035
# Epoch 35/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0027 - val_loss: 0.0032
# Epoch 36/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 0.0026 - val_loss: 0.0032
# Epoch 37/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 38/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0027 - val_loss: 0.0033
# Epoch 39/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - loss: 0.0027 - val_loss: 0.0033
# Epoch 40/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 41/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 42/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - loss: 0.0027 - val_loss: 0.0032
# Epoch 43/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 0.0026 - val_loss: 0.0032
# Epoch 44/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - loss: 0.0024 - val_loss: 0.0032
# Epoch 45/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 46/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 47/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.0025 - val_loss: 0.0031
# Epoch 48/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - loss: 0.0026 - val_loss: 0.0031
# Epoch 49/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 50/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - loss: 0.0025 - val_loss: 0.0033

# %% [markdown]
# ### **Evaluate**

# %%
# ========== Evaluate DL Models ==========
def evaluate_dl(model, X_test, y_test, name="DL Model", target="Solar"):
    preds = model.predict(X_test).flatten()
    rmse = np.sqrt(mean_squared_error(y_test, preds))
    mae  = mean_absolute_error(y_test, preds)
    r2   = r2_score(y_test, preds)

    print(f"\n{name} Performance on {target}:")
    print(f"RMSE: {rmse:.2f}, MAE: {mae:.2f}, R²: {r2:.3f}")

    # Plot Actual vs Predicted
    plt.figure(figsize=(10,5))
    plt.plot(y_test[:200], label="Actual")
    plt.plot(preds[:200], label="Predicted")
    plt.title(f"{name} - {target} Power Prediction (Sample of 200 hours)")
    plt.legend()
    plt.show()

    return {"Target": target, "Model": name, "RMSE": rmse, "MAE": mae, "R2": r2}

# %%
results_dl = []

# %%
# Solar
results_dl.append(evaluate_dl(lstm_solar, X_test_solar_dl, y_test_solar_dl, "LSTM", "Solar"))
results_dl.append(evaluate_dl(gru_solar,  X_test_solar_dl, y_test_solar_dl, "GRU", "Solar"))
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
#
# LSTM Performance on Solar:
# RMSE: 0.11, MAE: 0.07, R²: 0.706
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step
#
# GRU Performance on Solar:
# RMSE: 0.10, MAE: 0.06, R²: 0.779

# %%
# Wind
results_dl.append(evaluate_dl(lstm_wind, X_test_wind_dl, y_test_wind_dl, "LSTM", "Wind"))
results_dl.append(evaluate_dl(gru_wind,  X_test_wind_dl, y_test_wind_dl, "GRU", "Wind"))
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
#
# LSTM Performance on Wind:
# RMSE: 0.04, MAE: 0.02, R²: 0.969
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
#
# GRU Performance on Wind:
# RMSE: 0.04, MAE: 0.02, R²: 0.972

# %%
# Convert to DataFrame
results_dl_df = pd.DataFrame(results_dl)
print("\nFinal DL Results:\n", results_dl_df)
# Out:
# Final DL Results:
#    Target Model      RMSE       MAE        R2
# 0  Solar  LSTM  0.113114  0.068293  0.706084
# 1  Solar   GRU  0.098072  0.064296  0.779055
# 2   Wind  LSTM  0.037663  0.024636  0.968840
# 3   Wind   GRU  0.035937  0.023503  0.971630

# %% [markdown]
# ### **Comparison**

# %%
# Convert to DataFrames
results_ml_df = pd.DataFrame(results_ml)
results_dl_df = pd.DataFrame(results_dl)

# Combine
final_results = pd.concat([results_ml_df, results_dl_df], ignore_index=True)

# Show results
print("\n===== Final ML vs DL Comparison =====\n")
print(final_results)

# Save to CSV for research paper
final_results.to_csv("ML_DL_Comparison.csv", index=False)
# Out:
# ===== Final ML vs DL Comparison =====
#
#   Target          Model        RMSE         MAE        R2
# 0  Solar  Random Forest  390.483799  171.886996  0.864690
# 1  Solar        XGBoost  394.166178  178.854385  0.862126
# 2   Wind  Random Forest    0.662368    0.364053  1.000000
# 3   Wind        XGBoost    8.615146    5.012414  0.999940
# 4  Solar           LSTM    0.113114    0.068293  0.706084
# 5  Solar            GRU    0.098072    0.064296  0.779055
# 6   Wind           LSTM    0.037663    0.024636  0.968840
# 7   Wind            GRU    0.035937    0.023503  0.971630

# %%
def plot_comparison(y_test, preds_ml, preds_dl, target="Solar", model_ml="XGBoost", model_dl="LSTM", n=200):
    """
    Compare ML vs DL predictions with actual values.
    - y_test: actual test series
    - preds_ml: predictions from ML model
    - preds_dl: predictions from DL model
    - target: "Solar" or "Wind"
    - model_ml: ML model name (e.g., RF, XGB)
    - model_dl: DL model name (e.g., LSTM, GRU)
    - n: number of samples to plot
    """
    plt.figure(figsize=(12,6))
    plt.plot(y_test[:n], label="Actual", color="black", linewidth=2)
    plt.plot(preds_ml[:n], label=f"{model_ml} Prediction", linestyle="--")
    plt.plot(preds_dl[:n], label=f"{model_dl} Prediction", linestyle=":")

    plt.title(f"{target} Power Forecasting: Actual vs {model_ml} vs {model_dl} (Sample {n} hours)")
    plt.xlabel("Time Steps")
    plt.ylabel("Power Output")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# Solar: XGBoost vs LSTM
preds_ml_solar = xgb_solar.predict(X_test_solar_ml)
preds_dl_solar = lstm_solar.predict(X_test_solar_dl).flatten()

plot_comparison(y_test_solar_ml, preds_ml_solar, preds_dl_solar,
                target="Solar", model_ml="XGBoost", model_dl="LSTM")
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
# Wind: XGBoost vs GRU
preds_ml_wind = xgb_wind.predict(X_test_wind_ml)
preds_dl_wind = gru_wind.predict(X_test_wind_dl).flatten()

plot_comparison(y_test_wind_ml, preds_ml_wind, preds_dl_wind,
                target="Wind", model_ml="XGBoost", model_dl="GRU")
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
